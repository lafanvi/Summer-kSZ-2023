# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
import healpy as hp

# %%
B16_original = np.loadtxt("total_original_B16_agn", delimiter = ",")
B16_fixedk = np.loadtxt("total_original_B16_agn_fixedk", delimiter = ",")

# %%
B16_Arho0more = np.loadtxt("total_B16_custom_Arho0_10pmore_fixedk", delimiter = ",")
B16_Arho0less = np.loadtxt("total_B16_custom_Arho0_10pless_fixedk", delimiter = ",")
B16_Aalphamore = np.loadtxt("total_B16_custom_Aalpha_10pmore_fixedk", delimiter = ",")
B16_Aalphaless = np.loadtxt("total_B16_custom_Aalpha_10pless_fixedk", delimiter = ",")
B16_Abetamore = np.loadtxt("total_B16_custom_Abeta_10pmore_fixedk", delimiter = ",")
B16_Abetaless = np.loadtxt("total_B16_custom_Abeta_10pless_fixedk", delimiter = ",")

# %%
B16_alphammore = np.loadtxt("total_B16_custom_alpha_m_alpha_10pmore_fixedk", delimiter = ",")
B16_alphamless = np.loadtxt("total_B16_custom_alpha_m_alpha_10pless_fixedk", delimiter = ",")
B16_bmmore = np.loadtxt("total_B16_custom_alpha_m_beta_10pmore_fixedk", delimiter = ",")
B16_bmless = np.loadtxt("total_B16_custom_alpha_m_beta_10pless_fixedk", delimiter = ",")
B16_rmmore = np.loadtxt("total_B16_custom_alpha_m_rho0_10pmore_fixedk", delimiter = ",")
B16_rmless = np.loadtxt("total_B16_custom_alpha_m_rho0_10pless_fixedk", delimiter = ",")

# %%
B16_alphazmore = np.loadtxt("total_B16_custom_alpha_z_alpha_10pmore_fixedk", delimiter = ",")
B16_alphazless = np.loadtxt("total_B16_custom_alpha_z_alpha_10pless_fixedk", delimiter = ",")
B16_bzmore = np.loadtxt("total_B16_custom_alpha_z_beta_10pmore_fixedk", delimiter = ",")
B16_bzless = np.loadtxt("total_B16_custom_alpha_z_beta_10pless_fixedk", delimiter = ",")
B16_rzmore = np.loadtxt("total_B16_custom_alpha_z_rho0_10pmore_fixedk", delimiter = ",")
B16_rzless = np.loadtxt("total_B16_custom_alpha_z_rho0_10pless_fixedk", delimiter = ",")

# %%
plank_075 = np.loadtxt("total_B16_agn_plank_filter_NFW_0_75", delimiter = ",")
plank_1 = np.loadtxt("total_B16_agn_plank_filter_NFW_1", delimiter = ",")
plank_125 = np.loadtxt("total_B16_agn_plank_filter_NFW_1_25", delimiter = ",")
plank_15 = np.loadtxt("total_B16_agn_plank_filter_NFW_1_5", delimiter = ",")
plank_175 = np.loadtxt("total_B16_agn_plank_filter_NFW_1_75", delimiter = ",")
plank_2 = np.loadtxt("total_B16_agn_plank_filter_NFW_2", delimiter = ",")
plank_3 = np.loadtxt("total_B16_agn_plank_filter_NFW_3", delimiter = ",")
plank_4 = np.loadtxt("total_B16_agn_plank_filter_NFW_4", delimiter = ",")

# %%
so_1 = np.loadtxt("total_B16_agn_so_filter_NFW_1", delimiter = ",")
so_15 = np.loadtxt("total_B16_agn_so_filter_NFW_1_5", delimiter = ",")
so_2 = np.loadtxt("total_B16_agn_so_filter_NFW_2", delimiter = ",")
so_25 = np.loadtxt("total_B16_agn_so_filter_NFW_2_5", delimiter = ",")
so_3 = np.loadtxt("total_B16_agn_so_filter_NFW_3", delimiter = ",")
so_4 = np.loadtxt("total_B16_agn_so_filter_NFW_4", delimiter = ",")

# %%
s4_1 = np.loadtxt("total_B16_agn_s4_filter_NFW_1", delimiter = ",")
s4_2 = np.loadtxt("total_B16_agn_s4_filter_NFW_2", delimiter = ",")
s4_3 = np.loadtxt("total_B16_agn_s4_filter_NFW_3", delimiter = ",")
s4_4 = np.loadtxt("total_B16_agn_s4_filter_NFW_4", delimiter = ",")

# %%
kmin1e_0_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-0_kmax7", delimiter = ",")
kmin1e_1_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-1_kmax7", delimiter = ",")
kmin1e_2_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-2_kmax7", delimiter = ",")
kmin1e_3_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-3_kmax7", delimiter = ",")
#kmin1e_4_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax7", delimiter = ",")
kmin1e_5_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-5_kmax7", delimiter = ",")
kmin1e_6_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-6_kmax7", delimiter = ",")
kmin1e_7_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-7_kmax7", delimiter = ",")
kmin1e_15_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-15_kmax7", delimiter = ",")

kmin1e_4_kmax1 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax1", delimiter = ",")
kmin1e_4_kmax5 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax5", delimiter = ",")
kmin1e_4_kmax10 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax10", delimiter = ",")
kmin1e_4_kmax15 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax15", delimiter = ",")
kmin1e_4_kmax20 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax20", delimiter = ",")
kmin1e_4_kmax25 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax25", delimiter = ",")
kmin1e_4_kmax30 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax30", delimiter = ",")
kmin1e_4_kmax40 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax40", delimiter = ",")
kmin1e_4_kmax50 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax50", delimiter = ",")
kmin1e_4_kmax75 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax75", delimiter = ",")
kmin1e_4_kmax100 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax100", delimiter = ",")

#additional data I want after looking at the plots

# %%
kmin1e_4_kmax2 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax2", delimiter = ",")
kmin1e_4_kmax3 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax3", delimiter = ",")
kmin1e_4_kmax4 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax4", delimiter = ",")
kmin1e_4_kmax6 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax6", delimiter = ",")
kmin1e_4_kmax7 = np.loadtxt("total_B16_agn_so_filter_kmin1e-4_kmax7", delimiter = ",")

# %%
kmin1e_1 = np.loadtxt("kmin_1e1", delimiter = ",")
kmin1e_2 = np.loadtxt("kmin_1e2", delimiter = ",")
kmin1e_3 = np.loadtxt("kmin_1e3", delimiter = ",")
#kmin1e_4 = np.loadtxt("kmin_1e4", delimiter = ",")
kmin1e_5 = np.loadtxt("kmin_1e5", delimiter = ",")

# %%
kmax_1 = np.loadtxt("kmax_1", delimiter = ",")
kmax_3 = np.loadtxt("kmax_3", delimiter = ",")
kmax_5 = np.loadtxt("kmax_5", delimiter = ",")
#kmin1e_4 = np.loadtxt("kmin_1e4", delimiter = ",")
#kmax_9 = np.loadtxt("kmin_9", delimiter = ",")
#kmax_11 = np.loadtxt("kmin_11", delimiter = ",")
#kmax_13 = np.loadtxt("kmin_13", delimiter = ",")
kmax_15 = np.loadtxt("kmax_15", delimiter = ",")

# %%
ell_NFW = np.loadtxt("ell_NFW_tests", delimiter = ",")

# %%
s4_csz = np.loadtxt("total_B16_agn_s4_filter", delimiter = ",") #running class+sz after changing the filters
so_csz = np.loadtxt("total_B16_agn_so_filter", delimiter = ",")
planck_csz = np.loadtxt("total_B16_agn_planck_filter", delimiter = ",")

# %%
s4_corr = np.loadtxt("s4_kcmb_corr", delimiter = ",") # websky simulation results w different filters
so_corr = np.loadtxt("so_kcmb_corr", delimiter = ",")
planck_corr = np.loadtxt("plank_kcmb_corr", delimiter = ",")

# %%
kmin1e_0_kmax7.size
# Out:
# 70

# %%
ell_Kmima = np.delete(ell_NFW, -1)

# %%
ell = np.loadtxt("total_B16_custom_ell", delimiter = ",")

# %%
bin50 = np.arange(75, 10000, 50)

# %%
plt.figure(figsize=(10, 5))
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr, label = "so")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "plank")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, ".", label = "Websky", color = "blue")#
plt.plot(ell, B16_original, label = "Class_sz (Original)", color = "red")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#A related plots

plt.plot(ell, B16_Arho0more, label = "$A_0$ 10% more")
plt.plot(ell, B16_Arho0less, label = "$A_0$ 10% less")
plt.plot(ell, B16_Aalphamore, label = r"$A_\alpha$ 10% more")
plt.plot(ell, B16_Aalphaless, label = r"$A_\alpha$ 10% less")
plt.plot(ell, B16_Abetamore, label = r"$A_\beta$ 10% more")
plt.plot(ell, B16_Abetaless, label = r"$A_\beta$ 10% less")

#filter plots below

#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*planck_corr, label = "planck corr")
#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*so_corr, label = "so corr")
#plt.plot(bin50, bin50 * (bin50 + 1)*s4_corr, label = "s4 corr")

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing Gas Parameters (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,9000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("gas_plot.pdf")

# %%
plt.figure(figsize=(10, 5))
#plt.plot(filter_s0_clm0, filter_s0_clm1, label = "so")
#plt.plot(filter_p_clm0, filter_p_clm1, label = "plank")
#plt.plot(filter_clm0, filter_clm1, label = "original (s4)")
#plt.plot(ell, B16_original, label = "C_sz original agn")
plt.plot(ell, B16_fixedk, label = "Class_sz (original agn setting)")

#A related plots

plt.plot(ell, B16_rmmore, label = "m_rho0 10% more")
plt.plot(ell, B16_rmless, label = "m_rho0 10% less")
plt.plot(ell, B16_alphammore, label = "m_alpha 10% more")
plt.plot(ell, B16_alphamless, label = "m_alpha 10% less")
plt.plot(ell, B16_bmmore, label = "m_beta 10% more")
plt.plot(ell, B16_bmless, label = "m_beta 10% less")

#filter plots below

#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*planck_corr, label = "planck corr")
#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*so_corr, label = "so corr")
#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*s4_corr, label = "s4 corr")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, label = "Websky (s4 filter)")

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,9000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(10, 5))
#plt.plot(filter_s0_clm0, filter_s0_clm1, label = "so")
#plt.plot(filter_p_clm0, filter_p_clm1, label = "plank")
#plt.plot(filter_clm0, filter_clm1, label = "original (s4)")
#plt.plot(ell, B16_original, label = "C_sz original agn")
plt.plot(ell, B16_fixedk, label = "Class_sz (original agn setting)")

#A related plots

plt.plot(ell, B16_rzmore, label = "z_rho0 10% more")
plt.plot(ell, B16_rzless, label = "z_rho0 10% less")
plt.plot(ell, B16_alphazmore, label = "z_alpha 10% more")
plt.plot(ell, B16_alphazless, label = "z_alpha 10% less")
plt.plot(ell, B16_bzmore, label = "z_beta 10% more")
plt.plot(ell, B16_bzless, label = "z_beta 10% less")

#filter plots below

#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*planck_corr, label = "planck corr")
#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*so_corr, label = "so corr")
#plt.plot(bin50, bin50/(2*np.pi) * (bin50 + 1)*s4_corr, label = "s4 corr")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, label = "Websky (s4 filter)")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("$\ell$")
plt.ylabel("$\ell(\ell+1)C_{\ell}$ uK")
plt.title("Ksz^2-lensing plots")
plt.xlim(50,9000)
plt.ylim(1e-4,1.5e-1)
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(10, 5))
#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")# already 2pi

plt.plot(ell_NFW, s4_1, label = "Class_sz", color = "red")
#plt.plot(ell_NFW, s4_2, label = "Class_sz (NFW = 2)", color = "orange")
#plt.plot(ell_NFW, s4_3, label = "Class_sz (NFW = 3)", color = "green")
#plt.plot(ell_NFW, s4_4, label = "Class_sz (NFW = 4, $k_{min}$ = 1e-4, $k_{max} = 7$))", color = "purple")


#plt.plot(ell, so_csz, label = "Class_sz (so filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr, label = " Websky (so filter)")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "Websky (plank filter)")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi} uK^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("main_plot.pdf")

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")# already 2pi

plt.plot(ell_NFW, s4_1, label = "Class_sz (NFW = 1)", color = "red")
plt.plot(ell_NFW, s4_2, label = "Class_sz (NFW = 2)", color = "orange")
plt.plot(ell_NFW, s4_3, label = "Class_sz (NFW = 3)", color = "green")
plt.plot(ell_NFW, s4_4, label = "Class_sz (NFW = 4)", color = "purple")


#plt.plot(ell, so_csz, label = "Class_sz (so filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr, label = " Websky (so filter)")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "Websky (plank filter)")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi} uK^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing NFW Cutoff (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("NFW_plot.pdf")

# %%
#planck_corr

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
#plt.plot(bin50, bin50*(bin50+1)*s4_corr, label = "Websky (s4 filter)")# already 2pi


#plt.plot(ell, so_csz, label = "Class_sz (so filter)")
plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr, "o", label = " Websky", color = "Blue")

plt.plot(ell_NFW, so_1, label = "Class_sz (original)", color = "red")
#plt.plot(ell_NFW, so_2, label = "Class_sz (NFW = 2)", color ="orange")
#plt.plot(ell_NFW, so_3, label = "Class_sz (NFW = 3)", color = "green")
plt.plot(ell_NFW, so_4, label = "Class_sz (NFW = 4, $k_{min}$ = 1e-4, $k_{max} = 7$)", color = "purple")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "Websky (plank filter)")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing (SO filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("so_plot.pdf")

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
#plt.plot(bin50, bin50*(bin50+1)*s4_corr, label = "Websky (s4 filter)")# already 2pi


#plt.plot(ell, so_csz, label = "Class_sz (so filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr, label = " Websky (so filter)")

plt.plot(ell_NFW, plank_1, label = "Class_sz (original)", color = "red")
#plt.plot(ell_NFW, plank_2, label = "Class_sz (NFW = 2)")
#plt.plot(ell_NFW, plank_3, label = "Class_sz (NFW = 3)")
plt.plot(ell_NFW, plank_4, label = "Class_sz (NFW = 4, $k_{min}$ = 1e-4, $k_{max} = 7$)", color = "purple")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, ".", label = "Websky (plank filter)", color = "blue")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing (Planck filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("planck_plot.pdf")

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
#plt.plot(bin50, bin50*(bin50+1)*s4_corr, label = "Websky (s4 filter)")# already 2pi



#plt.plot(bin50, bin50/(2*np.pi)*(bin50+1)*so_corr, "o", label = "Websky", color = "blue")
#plt.plot(ell, so_csz, label = "Class_sz", color = "red")
plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr,"o", label = " Websky", color = "blue")

#plt.plot(ell_Kmima, kmin1e_0_kmax7, label = "$k_{min}$ = 1e0")
plt.plot(ell_Kmima, kmin1e_1_kmax7, label = "$k_{min}$ = 1e-1")
plt.plot(ell_Kmima, kmin1e_2_kmax7, label = "$k_{min}$ = 1e-2")
plt.plot(ell_Kmima, kmin1e_3_kmax7, label = "$k_{min}$ = 1e-3")
#plt.plot(ell, so_corr, label = "$k_{min}$ = 1e4", color = "red")
plt.plot(ell, so_csz, label = "$k_{min}$ = 1e-4", color = "red")

plt.plot(ell_Kmima, kmin1e_5_kmax7, label = "$k_{min}$ = 1e-5", color = "purple")
#plt.plot(ell_Kmima, kmin1e_6_kmax7, label = "$k_{min}$ = 1e-6")
#plt.plot(ell_Kmima, kmin1e_7_kmax7, label = "$k_{min}$ = 1e7", color = "purple")
#plt.plot(ell_Kmima, kmin1e_15_kmax7, label = "$k_{min}$ = 1e15")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "Websky (plank filter)")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing with $k_{min}$ variations(SO filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz", color = "red")
#plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")# already 2pi


#plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")


#plt.plot(ell, so_csz, label = "Class_sz", color = "red")
plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr,"o", label = " Websky", color = "blue")

#plt.plot(ell_Kmima, kmin1e_4_kmax5, label = "$k_{max}$ = 5")
#plt.plot(ell_Kmima, kmin1e_4_kmax1, label = "kmax = 1")

plt.plot(ell_Kmima, kmin1e_4_kmax2, label = "$k_{max}$ = 2")
plt.plot(ell_Kmima, kmin1e_4_kmax3, label = "$k_{max}$ = 3")
plt.plot(ell_Kmima, kmin1e_4_kmax5, label = "$k_{max}$ = 5")
plt.plot(ell, so_csz, label = "$k_{max}$ = 7", color = "red")
plt.plot(ell_Kmima, kmin1e_4_kmax10, label = "$k_{max}$ = 10")
plt.plot(ell_Kmima, kmin1e_4_kmax15, label = "$k_{max}$ = 15")
#plt.plot(ell_Kmima, kmin1e_4_kmax20, label = "$k_{max}$ = 20")
#plt.plot(ell_Kmima, kmin1e_4_kmax25, label = "$k_{max}$ = 25")
#plt.plot(ell_Kmima, kmin1e_4_kmax30, label = "kmax = 30")
#plt.plot(ell_Kmima, kmin1e_4_kmax40, label = "kmax = 40")
#plt.plot(ell_Kmima, kmin1e_4_kmax50, label = "kmax = 50")
#plt.plot(ell_Kmima, kmin1e_4_kmax75, label = "kmax = 75")
#plt.plot(ell_Kmima, kmin1e_4_kmax100, label = "kmax = 100")

#plt.plot(ell, planck_csz, label = "Class_sz", color = "red")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, "o", label = "Websky", color = "blue")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing with $k_{max}$ variations(SO filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()

# %%
ellkmin = np.arange(0, 10000, 50)

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")

#plt.plot(ell, s4_csz, label = "Class_sz (s4 filter)")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, ".",label = "Websky", color = "blue")# already 2pi



#plt.plot(bin50, bin50/(2*np.pi)*(bin50+1)*so_corr, "o", label = "Websky", color = "blue")
#plt.plot(ell, so_csz, label = "Class_sz", color = "red")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr,"o", label = " Websky", color = "blue")

#plt.plot(ell_Kmima, kmin1e_0_kmax7, label = "$k_{min}$ = 1e0")
plt.plot(ellkmin, kmin1e_1, label = "$k_{min}$ = 1e-1")
plt.plot(ellkmin, kmin1e_2, label = "$k_{min}$ = 1e-2")
plt.plot(ellkmin, kmin1e_3, label = "$k_{min}$ = 1e-3")
plt.plot(ell, s4_csz, label = "$k_{min}$ = 1e-4", color = "red")
#plt.plot(ell, so_corr, label = "$k_{min}$ = 1e4", color = "red")
#plt.plot(ell, so_csz, label = "$k_{min}$ = 1e-4", color = "red")

plt.plot(ellkmin, kmin1e_5, label = "$k_{min}$ = 1e-5", color = "purple")
#plt.plot(ell_Kmima, kmin1e_6_kmax7, label = "$k_{min}$ = 1e-6")
#plt.plot(ell_Kmima, kmin1e_7_kmax7, label = "$k_{min}$ = 1e7", color = "purple")
#plt.plot(ell_Kmima, kmin1e_15_kmax7, label = "$k_{min}$ = 1e15")

#plt.plot(ell, planck_csz, label = "Class_sz (planck filter)")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, label = "Websky (plank filter)")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi} uK^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing with $k_{min}$ variations (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("kmin_plot.pdf")

# %%
#

# %%
plt.figure(figsize=(10, 5))


#plt.plot(ell, B16_original, label = "Class_sz original s4")
#plt.plot(ell, B16_fixedk, label = "Class_sz (fixed k)")


plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")# already 2pi


#plt.plot(bin50, bin50*(bin50+1)*s4_corr, "o", label = "Websky", color = "blue")


#plt.plot(ell, so_csz, label = "Class_sz", color = "red")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*so_corr,"o", label = " Websky", color = "blue")

#plt.plot(ell_Kmima, kmin1e_4_kmax5, label = "$k_{max}$ = 5")
#plt.plot(ell_Kmima, kmin1e_4_kmax1, label = "kmax = 1")

plt.plot(ellkmin, kmax_1, label = "$k_{max}$ = 1")
plt.plot(ellkmin, kmax_3, label = "$k_{max}$ = 3")
plt.plot(ellkmin, kmax_5, label = "$k_{max}$ = 5")
plt.plot(ell, s4_csz, label = "$k_{max}$ = 7", color = "red")
#plt.plot(ell, so_csz, label = "$k_{max}$ = 7", color = "red")
#plt.plot(ell_Kmima, kmax10, label = "$k_{max}$ = 10")
plt.plot(ellkmin, kmax_15, label = "$k_{max}$ = 15", color = "purple")
#plt.plot(ell_Kmima, kmin1e_4_kmax20, label = "$k_{max}$ = 20")
#plt.plot(ell_Kmima, kmin1e_4_kmax25, label = "$k_{max}$ = 25")
#plt.plot(ell_Kmima, kmin1e_4_kmax30, label = "kmax = 30")
#plt.plot(ell_Kmima, kmin1e_4_kmax40, label = "kmax = 40")
#plt.plot(ell_Kmima, kmin1e_4_kmax50, label = "kmax = 50")
#plt.plot(ell_Kmima, kmin1e_4_kmax75, label = "kmax = 75")
#plt.plot(ell_Kmima, kmin1e_4_kmax100, label = "kmax = 100")

#plt.plot(ell, planck_csz, label = "Class_sz", color = "red")
#plt.plot(bin50, bin50*(bin50+1)/(2*np.pi)*planck_corr, "o", label = "Websky", color = "blue")



#A related plots

#filter plots below

plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title("kSZ$^2$ $\\times$ CMB lensing with $k_{max}$ variations (S4 filter - B16 AGN)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
plt.savefig("kmax_plot.pdf")

# %%
ell = np.loadtxt("err_ell", delimiter = ",")
vals = np.loadtxt("err_mes", delimiter = ",")
yerr_1 = np.loadtxt("yerr", delimiter = ",")

# %%
a_more = np.loadtxt( "alphamore" , delimiter = ",")
a_less = np.loadtxt( "alphaless" , delimiter = ",")
a_less_2 = np.loadtxt( "alphaless_2" , delimiter = ",")
a_more_2 = np.loadtxt( "alphamore_2" , delimiter = ",")

a_ell = np.loadtxt( "alpha_ell" , delimiter = ",")

# %%
plt.figure(figsize=(10, 5))
#plt.plot(bins_2, bins_2/(2*np.pi) * (bins_2 + 1) * vals_2, ".")
plt.errorbar(ell, ell/(2*np.pi) * (ell + 1) * vals, yerr = yerr_1, fmt = ".", label = "Websky measurement (w/noise)", color = "orange", capsize = 3)
#plt.plot(bins_2, bins_2/(2*np.pi) * (bins_2 + 1) * vals_2, ".")

#plt.plot(ell, ell/(2*np.pi) * (ell + 1) * temp2xkap_cross_corr, ".", label = "Websky S4 filter w/noise", color ="green")
plt.plot(bin50, bin50*(bin50+1)*s4_corr, ".", label = "Websky measurement (no noise)", color = "blue")
#plt.plot(bins, bins/(2*np.pi)*(bins+1)*vals, ".", label = "Websky S4 w/noise binned (50)", color = "purple")

plt.plot(a_ell, a_more, label = r"$A_\alpha$ 10% more", color = "green")
plt.plot(a_ell, a_more_2, label = r"$A_\alpha$ 15% more", color = "blue")
plt.plot(a_ell, a_less, label = r"$A_\alpha$ 10% less", color = "red")
plt.plot(a_ell, a_less_2, label = r"$A_\alpha$ 15% less", color = "purple")



#plt.xscale("log")
#plt.yscale("log")
#plt.xlim(50,8000)
#plt.ylim(1e-4,1.5e-1)
#plt.xlabel("$\ell$")
#plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$")
#plt.legend()
#plt.title("Cross corr ksz and kap (trial 2)")
#plt.grid()


plt.xscale("log")
plt.yscale("log") #in increasing order and specify the default value in class_sz
plt.xlabel("$\ell$", fontsize = 18)#cut_NFW
plt.ylabel(r"$\frac{\ell(\ell+1)C_{\ell}}{2\pi}$ uK$^2$", fontsize = 20) #over 2pi
#plt.ylabel(r"$\frac{3}{4}$", fontsize = 18) #over 2pi
plt.title(" Simulated CMB-S4 measurement of kSZ$^2$ $\\times$ CMB lensing)", fontsize = 18) 
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 12)
plt.xlim(60,5000)
plt.ylim(1e-4,1.5e-2)
plt.legend()
plt.grid()
